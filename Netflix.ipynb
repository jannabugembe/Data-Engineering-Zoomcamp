# %% [markdown]
# <a href="https://colab.research.google.com/github/jannabugembe/Data-Engineering-Zoomcamp/blob/main/Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
